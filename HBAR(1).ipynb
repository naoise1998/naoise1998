# %%
import matplotlib.pyplot as plt

# %%
plt.barh?

# %%
plt.barh(range(10),range(10),height=0.3)
# Out:
# <BarContainer object of 10 artists>

# %%
import random
d = [random.randint(1,100) for x in range(20)]

# %%
plt.barh(range(20),d,height=0.3)
# Out:
# <BarContainer object of 20 artists>

# %%
l = [1,5,3,4,0]
r = [4,9,10,12,9]
plt.barh([1,2,3,4,5],r,left=l,height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot([1,2,3,4],[4,2,5,2])

# %%
plt.Circle((1,1),0.2)

# %%
plt.show()

# %%
plt.scatter([1,2,3],[4,3,10])
